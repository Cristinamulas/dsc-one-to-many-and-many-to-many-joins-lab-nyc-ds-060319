# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data using one-to-many and many-to-many joins
# - Predict the resulting size of one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database

# %%
#Your code here
import sqlite3
import pandas as pd
c = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
c = c.cursor()

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code herecur.execute("""select firstName, lastName from employees join offices using(officeCode) where city = 'Boston';""")

c.execute(""" select firstName , lastName ,city ,state from employees join offices using(officeCode) order by firstName, lastName; """).fetchall()
# Out:
# [('Andy', 'Fixter', 'Sydney', ''),
#  ('Anthony', 'Bow', 'San Francisco', 'CA'),
#  ('Barry', 'Jones', 'London', ''),
#  ('Diane', 'Murphy', 'San Francisco', 'CA'),
#  ('Foon Yue', 'Tseng', 'NYC', 'NY'),
#  ('George', 'Vanauf', 'NYC', 'NY'),
#  ('Gerard', 'Bondur', 'Paris', ''),
#  ('Gerard', 'Hernandez', 'Paris', ''),
#  ('Jeff', 'Firrelli', 'San Francisco', 'CA'),
#  ('Julie', 'Firrelli', 'Boston', 'MA'),
#  ('Larry', 'Bott', 'London', ''),
#  ('Leslie', 'Jennings', 'San Francisco', 'CA'),
#  ('Leslie', 'Thompson', 'San Francisco', 'CA'),
#  ('Loui', 'Bondur', 'Paris', ''),
#  ('Mami', 'Nishi', 'Tokyo', 'Chiyoda-Ku'),
#  ('Martin', 'Gerard', 'Paris', ''),
#  ('Mary', 'Patterson', 'San Francisco', 'CA'),
#  ('Pamela', 'Castillo', 'Paris', ''),
#  ('Peter', 'Marsh', 'Sydney', ''),
#  ('Steve', 'Patterson', 'Boston', 'MA'),
#  ('Tom', 'King', 'Sydney', ''),
#  ('William', 'Patterson', 'Sydney', ''),
#  ('Yoshimi', 'Kato', 'Tokyo', 'Chiyoda-Ku')]

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all the customers first and last names along with a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
c.execute(""" select customerName,status, orderDate ,orderNumber from customers join orders using(customerNumber);""").fetchall()
# Out:
# [('Atelier graphique', 'Shipped', '2003-05-20', '10123'),
#  ('Atelier graphique', 'Shipped', '2004-09-27', '10298'),
#  ('Atelier graphique', 'Shipped', '2004-11-25', '10345'),
#  ('Signal Gift Stores', 'Shipped', '2003-05-21', '10124'),
#  ('Signal Gift Stores', 'Shipped', '2004-08-06', '10278'),
#  ('Signal Gift Stores', 'Shipped', '2004-11-29', '10346'),
#  ('Australian Collectors, Co.', 'Shipped', '2003-04-29', '10120'),
#  ('Australian Collectors, Co.', 'Shipped', '2003-05-21', '10125'),
#  ('Australian Collectors, Co.', 'Shipped', '2004-02-20', '10223'),
#  ('Australian Collectors, Co.', 'Shipped', '2004-11-24', '10342'),
#  ('Australian Collectors, Co.', 'Shipped', '2004-11-29', '10347'),
#  ('La Rochelle Gifts', 'Shipped', '2004-07-23', '10275'),
#  ('La Rochelle Gifts', 'Shipped', '2004-10-29', '10315'),
#  ('La Rochelle Gifts', 'Shipped', '2005-02-03', '10375'),
#  ('La Rochelle Gifts', 'In Process', '2005-05-31', '10425'),
#  ('Baane Mini Imports', 'Shipped', '2003-01-29', '10103'),
#  ('Baane Mini Imports', 'Shipped', '2003-10-10', '10158'),
#  ('Baane Mini Imports', 'Shipped', '2004-10-15', '10309'),
#  ('Baane Mini Imports', 'Shipped', '2004-11-05', '10325'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2003-03-26', '10113'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2003-07-02', '10135'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2003-08-08', '10142'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2003-11-12', '10182'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2004-03-11', '10229'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2004-07-20', '10271'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2004-08-20', '10282'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2004-10-21', '10312'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2004-11-19', '10335'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2004-12-10', '10357'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2005-01-19', '10368'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2005-01-23', '10371'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2005-02-17', '10382'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2005-02-28', '10385'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2005-03-04', '10390'),
#  ('Mini Gifts Distributors Ltd.', 'Shipped', '2005-03-23', '10396'),
#  ('Mini Gifts Distributors Ltd.', 'In Process', '2005-05-29', '10421'),
#  ('Blauer See Auto, Co.', 'Shipped', '2003-01-09', '10101'),
#  ('Blauer See Auto, Co.', 'Shipped', '2004-03-15', '10230'),
#  ('Blauer See Auto, Co.', 'Shipped', '2003-10-04', '10300'),
#  ('Blauer See Auto, Co.', 'Shipped', '2004-11-05', '10323'),
#  ('Mini Wheels Co.', 'Shipped', '2003-03-25', '10111'),
#  ('Mini Wheels Co.', 'Shipped', '2003-12-01', '10201'),
#  ('Mini Wheels Co.', 'Shipped', '2004-11-18', '10333'),
#  ('Land of Toys Inc.', 'Shipped', '2003-02-24', '10107'),
#  ('Land of Toys Inc.', 'Cancelled', '2004-05-07', '10248'),
#  ('Land of Toys Inc.', 'Shipped', '2004-09-08', '10292'),
#  ('Land of Toys Inc.', 'Shipped', '2004-11-15', '10329'),
#  ('Euro+ Shopping Channel', 'Shipped', '2003-01-31', '10104'),
#  ('Euro+ Shopping Channel', 'Shipped', '2003-06-06', '10128'),
#  ('Euro+ Shopping Channel', 'Shipped', '2003-06-27', '10133'),
#  ('Euro+ Shopping Channel', 'Shipped', '2003-09-28', '10153'),
#  ('Euro+ Shopping Channel', 'Shipped', '2003-10-08', '10156'),
#  ('Euro+ Shopping Channel', 'Shipped', '2003-11-19', '10190'),
#  ('Euro+ Shopping Channel', 'Shipped', '2003-12-02', '10203'),
#  ('Euro+ Shopping Channel', 'Shipped', '2003-12-03', '10205'),
#  ('Euro+ Shopping Channel', 'Shipped', '2004-01-16', '10212'),
#  ('Euro+ Shopping Channel', 'Shipped', '2004-04-29', '10244'),
#  ('Euro+ Shopping Channel', 'Shipped', '2004-05-05', '10246'),
#  ('Euro+ Shopping Channel', 'Cancelled', '2004-06-24', '10262'),
#  ('Euro+ Shopping Channel', 'Shipped', '2004-08-09', '10279'),
#  ('Euro+ Shopping Channel', 'Shipped', '2004-10-16', '10311'),
#  ('Euro+ Shopping Channel', 'Shipped', '2004-12-02', '10350'),
#  ('Euro+ Shopping Channel', 'Shipped', '2004-12-07', '10355'),
#  ('Euro+ Shopping Channel', 'Shipped', '2004-12-10', '10358'),
#  ('Euro+ Shopping Channel', 'Shipped', '2005-02-10', '10378'),
#  ('Euro+ Shopping Channel', 'Shipped', '2005-02-10', '10379'),
#  ('Euro+ Shopping Channel', 'Shipped', '2005-02-16', '10380'),
#  ('Euro+ Shopping Channel', 'Shipped', '2005-02-22', '10383'),
#  ('Euro+ Shopping Channel', 'Resolved', '2005-03-01', '10386'),
#  ('Euro+ Shopping Channel', 'Shipped', '2005-03-15', '10394'),
#  ('Euro+ Shopping Channel', 'Shipped', '2005-05-03', '10412'),
#  ('Euro+ Shopping Channel', 'Disputed', '2005-05-13', '10417'),
#  ('Euro+ Shopping Channel', 'In Process', '2005-05-31', '10424'),
#  ('Volvo Model Replicas, Co', 'Shipped', '2003-03-24', '10112'),
#  ('Volvo Model Replicas, Co', 'Shipped', '2004-11-03', '10320'),
#  ('Volvo Model Replicas, Co', 'Shipped', '2004-11-09', '10326'),
#  ('Volvo Model Replicas, Co', 'On Hold', '2004-11-19', '10334'),
#  ('Danish Wholesale Imports', 'Shipped', '2003-02-11', '10105'),
#  ('Danish Wholesale Imports', 'Shipped', '2004-04-09', '10238'),
#  ('Danish Wholesale Imports', 'Shipped', '2004-06-08', '10256'),
#  ('Danish Wholesale Imports', 'Resolved', '2004-11-10', '10327'),
#  ('Danish Wholesale Imports', 'Disputed', '2005-04-15', '10406'),
#  ('Saveley & Henriot, Co.', 'Shipped', '2003-11-25', '10194'),
#  ('Saveley & Henriot, Co.', 'Shipped', '2004-01-02', '10208'),
#  ('Saveley & Henriot, Co.', 'Shipped', '2004-03-02', '10227'),
#  ('Dragon Souveniers, Ltd.', 'Shipped', '2003-04-16', '10117'),
#  ('Dragon Souveniers, Ltd.', 'Shipped', '2003-09-19', '10150'),
#  ('Dragon Souveniers, Ltd.', 'Shipped', '2003-10-22', '10165'),
#  ('Dragon Souveniers, Ltd.', 'Shipped', '2004-08-04', '10277'),
#  ('Dragon Souveniers, Ltd.', 'Shipped', '2005-03-02', '10387'),
#  ('Muscle Machine Inc', 'Shipped', '2003-06-03', '10127'),
#  ('Muscle Machine Inc', 'Shipped', '2003-12-02', '10204'),
#  ('Muscle Machine Inc', 'Shipped', '2004-07-07', '10267'),
#  ('Muscle Machine Inc', 'Shipped', '2004-12-01', '10349'),
#  ('Diecast Classics Inc.', 'Shipped', '2004-07-20', '10272'),
#  ('Diecast Classics Inc.', 'Shipped', '2004-08-19', '10281'),
#  ('Diecast Classics Inc.', 'Shipped', '2004-11-02', '10318'),
#  ('Diecast Classics Inc.', 'In Process', '2005-05-30', '10422'),
#  ('Technics Stores Inc.', 'Shipped', '2003-07-24', '10140'),
#  ('Technics Stores Inc.', 'Shipped', '2003-10-28', '10168'),
#  ('Technics Stores Inc.', 'Shipped', '2004-11-02', '10317'),
#  ('Technics Stores Inc.', 'Shipped', '2005-01-05', '10362'),
#  ('Handji Gifts& Co', 'Shipped', '2004-02-04', '10217'),
#  ('Handji Gifts& Co', 'Shipped', '2004-06-15', '10259'),
#  ('Handji Gifts& Co', 'Shipped', '2004-09-01', '10288'),
#  ('Handji Gifts& Co', 'Shipped', '2005-04-23', '10409'),
#  ('Herkku Gifts', 'Shipped', '2003-11-12', '10181'),
#  ('Herkku Gifts', 'Shipped', '2003-11-18', '10188'),
#  ('Herkku Gifts', 'Shipped', '2004-09-03', '10289'),
#  ('Daedalus Designs Imports', 'Shipped', '2003-11-11', '10180'),
#  ('Daedalus Designs Imports', 'Shipped', '2004-02-21', '10224'),
#  ("La Corne D'abondance, Co.", 'Shipped', '2003-04-01', '10114'),
#  ("La Corne D'abondance, Co.", 'Shipped', '2004-08-28', '10286'),
#  ("La Corne D'abondance, Co.", 'Shipped', '2004-11-20', '10336'),
#  ('Cambridge Collectables Co.', 'Shipped', '2004-03-10', '10228'),
#  ('Cambridge Collectables Co.', 'Shipped', '2004-05-08', '10249'),
#  ('Gift Depot Inc.', 'Shipped', '2003-11-05', '10172'),
#  ('Gift Depot Inc.', 'Shipped', '2004-06-28', '10263'),
#  ('Gift Depot Inc.', 'Shipped', '2005-05-05', '10413'),
#  ('Osaka Souveniers Co.', 'Shipped', '2004-01-12', '10210'),
#  ('Osaka Souveniers Co.', 'Shipped', '2004-04-13', '10240'),
#  ('Vitachrome Inc.', 'Shipped', '2003-01-10', '10102'),
#  ('Vitachrome Inc.', 'Shipped', '2004-04-05', '10237'),
#  ('Vitachrome Inc.', 'Shipped', '2004-11-05', '10324'),
#  ('Toys of Finland, Co.', 'Shipped', '2003-10-06', '10155'),
#  ('Toys of Finland, Co.', 'Shipped', '2004-09-30', '10299'),
#  ('Toys of Finland, Co.', 'Shipped', '2005-02-09', '10377'),
#  ('AV Stores, Co.', 'Shipped', '2003-03-18', '10110'),
#  ('AV Stores, Co.', 'Shipped', '2004-10-14', '10306'),
#  ('AV Stores, Co.', 'Shipped', '2004-11-17', '10332'),
#  ('Clover Collections, Co.', 'Shipped', '2004-02-12', '10220'),
#  ('Clover Collections, Co.', 'Shipped', '2004-09-16', '10297'),
#  ('Auto-Moto Classics Inc.', 'Shipped', '2003-06-16', '10130'),
#  ('Auto-Moto Classics Inc.', 'Shipped', '2004-09-07', '10290'),
#  ('Auto-Moto Classics Inc.', 'Shipped', '2004-12-03', '10352'),
#  ('UK Collectables, Ltd.', 'Cancelled', '2004-06-01', '10253'),
#  ('UK Collectables, Ltd.', 'Shipped', '2003-10-06', '10302'),
#  ('UK Collectables, Ltd.', 'Shipped', '2005-04-08', '10403'),
#  ('Canadian Gift Exchange Network', 'Shipped', '2003-12-05', '10206'),
#  ('Canadian Gift Exchange Network', 'Shipped', '2004-10-22', '10313'),
#  ('Online Mini Collectables', 'Shipped', '2004-08-02', '10276'),
#  ('Online Mini Collectables', 'Shipped', '2004-09-10', '10294'),
#  ('Toys4GrownUps.com', 'Shipped', '2003-08-25', '10145'),
#  ('Toys4GrownUps.com', 'Shipped', '2003-11-18', '10189'),
#  ('Toys4GrownUps.com', 'Resolved', '2005-01-12', '10367'),
#  ('Mini Caravy', 'Shipped', '2004-04-13', '10241'),
#  ('Mini Caravy', 'Shipped', '2004-06-04', '10255'),
#  ('Mini Caravy', 'Shipped', '2005-04-14', '10405'),
#  ('King Kong Collectables, Co.', 'Shipped', '2003-11-15', '10187'),
#  ('King Kong Collectables, Co.', 'Shipped', '2003-12-01', '10200'),
#  ('Enaco Distributors', 'Shipped', '2003-04-21', '10118'),
#  ('Enaco Distributors', 'Shipped', '2003-11-26', '10197'),
#  ('Enaco Distributors', 'Shipped', '2004-11-24', '10340'),
#  ('Boards & Toys Co.', 'Shipped', '2003-10-02', '10154'),
#  ('Boards & Toys Co.', 'Shipped', '2005-02-08', '10376'),
#  ('Heintze Collectables', 'Shipped', '2003-10-17', '10161'),
#  ('Heintze Collectables', 'Shipped', '2004-10-22', '10314'),
#  ('Québec Home Shopping Network', 'Shipped', '2003-11-05', '10171'),
#  ('Québec Home Shopping Network', 'Shipped', '2004-06-17', '10261'),
#  ('Québec Home Shopping Network', 'Shipped', '2005-05-01', '10411'),
#  ('Collectable Mini Designs Co.', 'Shipped', '2004-02-19', '10222'),
#  ('Collectable Mini Designs Co.', 'Shipped', '2004-02-26', '10226'),
#  ('giftsbymail.co.uk', 'Shipped', '2004-03-20', '10232'),
#  ('giftsbymail.co.uk', 'Shipped', '2004-11-01', '10316'),
#  ('Alpha Cognac', 'Shipped', '2003-07-04', '10136'),
#  ('Alpha Cognac', 'Shipped', '2003-11-08', '10178'),
#  ('Alpha Cognac', 'Shipped', '2005-03-28', '10397'),
#  ('Amica Models & Co.', 'Shipped', '2004-08-17', '10280'),
#  ('Amica Models & Co.', 'Shipped', '2004-09-09', '10293'),
#  ('Lyon Souveniers', 'Shipped', '2003-07-01', '10134'),
#  ('Lyon Souveniers', 'Shipped', '2004-12-09', '10356'),
#  ('Lyon Souveniers', 'Shipped', '2005-03-17', '10395'),
#  ('Auto Associés & Cie.', 'Shipped', '2004-02-02', '10216'),
#  ('Auto Associés & Cie.', 'Shipped', '2004-10-11', '10304'),
#  ('Toms Spezialitäten, Ltd', 'Shipped', '2003-11-20', '10191'),
#  ('Toms Spezialitäten, Ltd', 'Shipped', '2004-10-16', '10310'),
#  ('Royal Canadian Collectables, Ltd.', 'Shipped', '2004-04-02', '10235'),
#  ('Royal Canadian Collectables, Ltd.', 'Shipped', '2004-08-20', '10283'),
#  ("Anna's Decorations, Ltd", 'Shipped', '2003-09-11', '10148'),
#  ("Anna's Decorations, Ltd", 'Shipped', '2003-11-04', '10169'),
#  ("Anna's Decorations, Ltd", 'Shipped', '2005-01-20', '10370'),
#  ("Anna's Decorations, Ltd", 'Shipped', '2005-03-09', '10391'),
#  ('Rovelli Gifts', 'Shipped', '2003-02-17', '10106'),
#  ('Rovelli Gifts', 'Shipped', '2003-11-05', '10173'),
#  ('Rovelli Gifts', 'Shipped', '2004-11-12', '10328'),
#  ('Souveniers And Things Co.', 'Shipped', '2003-07-16', '10139'),
#  ('Souveniers And Things Co.', 'Shipped', '2004-07-19', '10270'),
#  ('Souveniers And Things Co.', 'Shipped', '2004-12-17', '10361'),
#  ('Souveniers And Things Co.', 'In Process', '2005-05-29', '10420'),
#  ("Marta's Replicas Co.", 'Shipped', '2004-08-27', '10285'),
#  ("Marta's Replicas Co.", 'Shipped', '2004-10-13', '10305'),
#  ('Vida Sport, Ltd', 'Shipped', '2004-02-22', '10225'),
#  ('Vida Sport, Ltd', 'Shipped', '2004-08-30', '10287'),
#  ('Norway Gifts By Mail, Co.', 'Shipped', '2004-08-21', '10284'),
#  ('Norway Gifts By Mail, Co.', 'Shipped', '2003-10-05', '10301'),
#  ('Oulu Toy Supplies, Inc.', 'Shipped', '2003-09-21', '10151'),
#  ('Oulu Toy Supplies, Inc.', 'Shipped', '2004-04-12', '10239'),
#  ('Oulu Toy Supplies, Inc.', 'Shipped', '2005-01-31', '10373'),
#  ('Petit Auto', 'Shipped', '2004-02-18', '10221'),
#  ('Petit Auto', 'Shipped', '2004-07-21', '10273'),
#  ('Petit Auto', 'In Process', '2005-05-30', '10423'),
#  ('Mini Classics', 'Shipped', '2003-11-25', '10195'),
#  ('Mini Classics', 'Shipped', '2004-10-15', '10308'),
#  ('Mini Creations Ltd.', 'Shipped', '2003-08-10', '10143'),
#  ('Mini Creations Ltd.', 'Shipped', '2003-11-14', '10185'),
#  ('Mini Creations Ltd.', 'Shipped', '2005-01-07', '10365'),
#  ('Corporate Gift Ideas Co.', 'Shipped', '2003-10-10', '10159'),
#  ('Corporate Gift Ideas Co.', 'Shipped', '2003-10-18', '10162'),
#  ('Corporate Gift Ideas Co.', 'Shipped', '2005-02-17', '10381'),
#  ('Corporate Gift Ideas Co.', 'Shipped', '2005-02-23', '10384'),
#  ('Down Under Souveniers, Inc', 'Shipped', '2003-06-25', '10132'),
#  ('Down Under Souveniers, Inc', 'Shipped', '2004-06-03', '10254'),
#  ('Down Under Souveniers, Inc', 'Shipped', '2004-12-04', '10354'),
#  ('Down Under Souveniers, Inc', 'Shipped', '2005-03-11', '10393'),
#  ('Down Under Souveniers, Inc', 'Shipped', '2005-04-08', '10404'),
#  ('Stylish Desk Decors, Co.', 'Shipped', '2003-06-12', '10129'),
#  ('Stylish Desk Decors, Co.', 'Shipped', '2003-11-06', '10175'),
#  ('Stylish Desk Decors, Co.', 'Shipped', '2004-12-03', '10351'),
#  ('Tekni Collectables Inc.', 'Shipped', '2004-03-29', '10233'),
#  ('Tekni Collectables Inc.', 'Shipped', '2004-05-18', '10251'),
#  ('Tekni Collectables Inc.', 'On Hold', '2005-04-03', '10401'),
#  ('Australian Gift Network, Co', 'Shipped', '2003-09-25', '10152'),
#  ('Australian Gift Network, Co', 'Shipped', '2003-11-06', '10174'),
#  ('Australian Gift Network, Co', 'Shipped', '2005-02-02', '10374'),
#  ('Suominen Souveniers', 'Shipped', '2003-08-01', '10141'),
#  ('Suominen Souveniers', 'Shipped', '2004-05-05', '10247'),
#  ('Suominen Souveniers', 'Shipped', '2005-01-06', '10363'),
#  ('Classic Gift Ideas, Inc', 'Shipped', '2003-11-13', '10183'),
#  ('Classic Gift Ideas, Inc', 'Shipped', '2004-10-14', '10307'),
#  ('CAF Imports', 'Shipped', '2003-11-07', '10177'),
#  ('CAF Imports', 'Shipped', '2004-03-19', '10231'),
#  ("Men 'R' US Retailers, Ltd.", 'Shipped', '2003-10-11', '10160'),
#  ("Men 'R' US Retailers, Ltd.", 'Shipped', '2004-01-09', '10209'),
#  ('Marseille Mini Autos', 'Shipped', '2003-05-08', '10122'),
#  ('Marseille Mini Autos', 'Shipped', '2004-11-25', '10344'),
#  ('Marseille Mini Autos', 'Shipped', '2005-01-06', '10364'),
#  ('Reims Collectables', 'Shipped', '2003-05-07', '10121'),
#  ('Reims Collectables', 'Shipped', '2003-07-10', '10137'),
#  ('Reims Collectables', 'Shipped', '2004-11-24', '10343'),
#  ('Reims Collectables', 'Shipped', '2004-12-15', '10359'),
#  ('Reims Collectables', 'Shipped', '2005-03-30', '10398'),
#  ('GiftsForHim.com', 'Shipped', '2003-12-02', '10202'),
#  ('GiftsForHim.com', 'Cancelled', '2004-06-16', '10260'),
#  ('GiftsForHim.com', 'Shipped', '2005-04-29', '10410'),
#  ('Gifts4AllAges.com', 'Shipped', '2004-06-30', '10264'),
#  ('Gifts4AllAges.com', 'Shipped', '2004-09-10', '10295'),
#  ('Gifts4AllAges.com', 'On Hold', '2005-05-06', '10414'),
#  ('Online Diecast Creations Co.', 'Shipped', '2003-01-06', '10100'),
#  ('Online Diecast Creations Co.', 'Shipped', '2003-11-20', '10192'),
#  ('Online Diecast Creations Co.', 'Shipped', '2004-11-04', '10322'),
#  ('Collectables For Less Inc.', 'Shipped', '2003-09-05', '10147'),
#  ('Collectables For Less Inc.', 'Shipped', '2004-07-21', '10274'),
#  ('Collectables For Less Inc.', 'Shipped', '2005-01-20', '10369'),
#  ('Royale Belge', 'Shipped', '2003-04-11', '10116'),
#  ('Royale Belge', 'Shipped', '2003-08-13', '10144'),
#  ('Royale Belge', 'Shipped', '2004-11-22', '10338'),
#  ('Royale Belge', 'Shipped', '2005-01-10', '10366'),
#  ('Salzburg Collectables', 'Shipped', '2003-04-28', '10119'),
#  ('Salzburg Collectables', 'Shipped', '2004-07-16', '10269'),
#  ('Salzburg Collectables', 'Shipped', '2004-11-24', '10341'),
#  ('Salzburg Collectables', 'Shipped', '2005-05-17', '10419'),
#  ('Cruz & Sons Co.', 'Shipped', '2003-03-03', '10108'),
#  ('Cruz & Sons Co.', 'Shipped', '2003-11-27', '10198'),
#  ('Cruz & Sons Co.', 'Shipped', '2004-11-16', '10330'),
#  ("L'ordine Souveniers", 'Shipped', '2003-11-06', '10176'),
#  ("L'ordine Souveniers", 'Shipped', '2004-07-06', '10266'),
#  ("L'ordine Souveniers", 'Shipped', '2005-05-10', '10416'),
#  ('Tokyo Collectables, Ltd', 'Shipped', '2004-06-15', '10258'),
#  ('Tokyo Collectables, Ltd', 'Shipped', '2004-11-23', '10339'),
#  ('Tokyo Collectables, Ltd', 'Shipped', '2005-01-26', '10372'),
#  ('Tokyo Collectables, Ltd', 'Shipped', '2005-04-22', '10408'),
#  ('Auto Canal+ Petit', 'Shipped', '2004-01-15', '10211'),
#  ('Auto Canal+ Petit', 'Shipped', '2004-05-26', '10252'),
#  ('Auto Canal+ Petit', 'Shipped', '2005-04-07', '10402'),
#  ('Extreme Desk Decorations, Ltd', 'Shipped', '2004-03-30', '10234'),
#  ('Extreme Desk Decorations, Ltd', 'Shipped', '2004-07-12', '10268'),
#  ('Extreme Desk Decorations, Ltd', 'Shipped', '2005-05-16', '10418'),
#  ('Bavarian Collectables Imports, Co.', 'Shipped', '2004-09-15', '10296'),
#  ('Classic Legends Inc.', 'Shipped', '2003-04-04', '10115'),
#  ('Classic Legends Inc.', 'Shipped', '2003-10-20', '10163'),
#  ('Classic Legends Inc.', 'Shipped', '2004-11-21', '10337'),
#  ('Gift Ideas Corp.', 'Shipped', '2003-06-16', '10131'),
#  ('Gift Ideas Corp.', 'Shipped', '2003-09-03', '10146'),
#  ('Gift Ideas Corp.', 'Shipped', '2004-12-04', '10353'),
#  ('Scandinavian Gift Ideas', 'Cancelled', '2003-10-23', '10167'),
#  ('Scandinavian Gift Ideas', 'Shipped', '2004-09-08', '10291'),
#  ('Scandinavian Gift Ideas', 'Shipped', '2005-03-03', '10389'),
#  ('The Sharp Gifts Warehouse', 'Shipped', '2004-05-11', '10250'),
#  ('The Sharp Gifts Warehouse', 'Shipped', '2004-06-14', '10257'),
#  ('The Sharp Gifts Warehouse', 'Shipped', '2005-04-01', '10400'),
#  ('The Sharp Gifts Warehouse', 'On Hold', '2005-04-22', '10407'),
#  ('Mini Auto Werke', 'Resolved', '2003-10-21', '10164'),
#  ('Mini Auto Werke', 'Shipped', '2003-11-04', '10170'),
#  ('Mini Auto Werke', 'Shipped', '2005-03-10', '10392'),
#  ('Super Scale Inc.', 'Shipped', '2003-11-26', '10196'),
#  ('Super Scale Inc.', 'Shipped', '2004-05-04', '10245'),
#  ('Microscale Inc.', 'Shipped', '2004-04-20', '10242'),
#  ('Microscale Inc.', 'Shipped', '2004-11-03', '10319'),
#  ('Corrida Auto Replicas, Ltd', 'Shipped', '2003-05-28', '10126'),
#  ('Corrida Auto Replicas, Ltd', 'Shipped', '2004-01-26', '10214'),
#  ('Corrida Auto Replicas, Ltd', 'Shipped', '2004-11-01', '10348'),
#  ('FunGiftIdeas.com', 'Shipped', '2003-10-21', '10166'),
#  ('FunGiftIdeas.com', 'Shipped', '2004-11-04', '10321'),
#  ('FunGiftIdeas.com', 'Shipped', '2005-03-03', '10388'),
#  ('Australian Collectables, Ltd', 'Shipped', '2003-11-21', '10193'),
#  ('Australian Collectables, Ltd', 'Shipped', '2004-07-02', '10265'),
#  ('Australian Collectables, Ltd', 'Disputed', '2005-05-09', '10415'),
#  ('Frau da Collezione', 'Shipped', '2003-10-09', '10157'),
#  ('Frau da Collezione', 'Shipped', '2004-02-09', '10218'),
#  ('West Coast Collectables Co.', 'Shipped', '2003-12-01', '10199'),
#  ('West Coast Collectables Co.', 'Shipped', '2004-01-29', '10215'),
#  ('Iberia Gift Imports, Corp.', 'Shipped', '2003-11-14', '10184'),
#  ('Iberia Gift Imports, Corp.', 'Shipped', '2004-10-06', '10303'),
#  ('Motor Mint Distributors Inc.', 'Shipped', '2003-03-10', '10109'),
#  ('Motor Mint Distributors Inc.', 'Shipped', '2004-04-03', '10236'),
#  ('Motor Mint Distributors Inc.', 'Shipped', '2004-11-17', '10331'),
#  ('Signal Collectibles Ltd.', 'Shipped', '2003-09-12', '10149'),
#  ('Signal Collectibles Ltd.', 'Shipped', '2004-02-10', '10219'),
#  ('Double Decker Gift Stores, Ltd', 'Shipped', '2003-11-14', '10186'),
#  ('Double Decker Gift Stores, Ltd', 'Shipped', '2004-01-22', '10213'),
#  ('Diecast Collectables', 'Shipped', '2003-12-09', '10207'),
#  ('Diecast Collectables', 'Shipped', '2004-04-26', '10243'),
#  ("Kelly's Gift Shop", 'Shipped', '2003-07-07', '10138'),
#  ("Kelly's Gift Shop", 'Cancelled', '2003-11-11', '10179'),
#  ("Kelly's Gift Shop", 'Shipped', '2004-12-16', '10360'),
#  ("Kelly's Gift Shop", 'Shipped', '2005-04-01', '10399')]

# %% [markdown]
# ## Customers and their Payments (another One-to-Many join)
#
# Return a list of customers first and last names along with details about their payments including the amount and date of payments. Sort these results in descending order by the payment amount.

# %%
# Your code here
c.execute(""" select customerName , paymentDate , amount from customers join payments using(customerNumber) order by amount desc""").fetchall()
# Out:
# [('FunGiftIdeas.com', '2003-11-08', '9977.85'),
#  ('Australian Gift Network, Co', '2003-10-17', '9821.32'),
#  ('Auto-Moto Classics Inc.', '2004-12-06', '9658.74'),
#  ('Australian Collectables, Ltd', '2004-07-28', '9415.13'),
#  ('Mini Auto Werke', '2005-05-03', '8807.12'),
#  ('Corporate Gift Ideas Co.', '2003-11-03', '85559.12'),
#  ('Mini Gifts Distributors Ltd.', '2004-08-28', '85410.87'),
#  ('Herkku Gifts', '2003-12-03', '85024.46'),
#  ('Mini Gifts Distributors Ltd.', '2005-04-16', '83598.04'),
#  ('Mini Creations Ltd.', '2005-01-18', '8307.28'),
#  ('Australian Collectors, Co.', '2004-12-15', '82261.22'),
#  ('Collectable Mini Designs Co.', '2004-03-15', '80375.24'),
#  ('West Coast Collectables Co.', '2003-12-09', '7678.25'),
#  ('Volvo Model Replicas, Co', '2003-04-09', '7674.94'),
#  ('Frau da Collezione', '2004-02-17', '7612.06'),
#  ('Australian Collectors, Co.', '2003-05-31', '7565.08'),
#  ('Down Under Souveniers, Inc', '2005-05-23', '75020.13'),
#  ('Blauer See Auto, Co.', '2004-11-18', '7466.32'),
#  ('Double Decker Gift Stores, Ltd', '2004-01-31', '7310.42'),
#  ('Tekni Collectables Inc.', '2004-04-16', '7178.66'),
#  ('Gift Ideas Corp.', '2003-09-15', '6631.36'),
#  ('Euro+ Shopping Channel', '2005-03-25', '65071.26'),
#  ('Salzburg Collectables', '2004-08-01', '6419.84'),
#  ('Euro+ Shopping Channel', '2003-12-09', '63843.55'),
#  ('Diecast Classics Inc.', '2004-09-07', '63357.13'),
#  ('Diecast Collectables', '2004-05-14', '6276.60'),
#  ('Tokyo Collectables, Ltd', '2005-05-18', '615.45'),
#  ('Vida Sport, Ltd', '2004-09-18', '61402.00'),
#  ('Toms Spezialitäten, Ltd', '2004-11-06', '61234.67'),
#  ('Atelier graphique', '2004-10-19', '6066.78'),
#  ('Auto-Moto Classics Inc.', '2003-07-06', '6036.96'),
#  ('Euro+ Shopping Channel', '2004-01-30', '59830.55'),
#  ('The Sharp Gifts Warehouse', '2004-06-21', '59551.38'),
#  ('Diecast Collectables', '2003-12-26', '59265.14'),
#  ('Motor Mint Distributors Inc.', '2004-04-14', '5899.38'),
#  ('Muscle Machine Inc', '2003-06-18', '58841.35'),
#  ('Muscle Machine Inc', '2003-12-22', '58793.53'),
#  ('Auto-Moto Classics Inc.', '2004-09-21', '5858.56'),
#  ('Auto Associés & Cie.', '2004-02-10', '5759.42'),
#  ('Corrida Auto Replicas, Ltd', '2003-06-13', '57131.92'),
#  ('Mini Gifts Distributors Ltd.', '2004-11-02', '55639.66'),
#  ('Online Diecast Creations Co.', '2003-12-05', '55425.77'),
#  ('Vitachrome Inc.', '2003-01-30', '5494.78'),
#  ('Danish Wholesale Imports', '2003-02-20', '53959.21'),
#  ('Heintze Collectables', '2004-11-02', '53745.34'),
#  ('Auto Associés & Cie.', '2004-10-22', '53116.99'),
#  ('AV Stores, Co.', '2004-11-03', '52825.29'),
#  ('Mini Creations Ltd.', '2003-11-24', '52548.49'),
#  ("Kelly's Gift Shop", '2004-12-31', '52166.00'),
#  ('Rovelli Gifts', '2003-03-02', '52151.81'),
#  ("L'ordine Souveniers", '2004-07-18', '51619.02'),
#  ("La Corne D'abondance, Co.", '2004-12-04', '51209.58'),
#  ('Online Mini Collectables', '2004-08-13', '51152.86'),
#  ('Cruz & Sons Co.', '2003-03-09', '51001.22'),
#  ('Marseille Mini Autos', '2003-05-25', '50824.66'),
#  ('Online Diecast Creations Co.', '2004-11-17', '50799.69'),
#  ('Technics Stores Inc.', '2003-11-18', '50743.65'),
#  ('Toys4GrownUps.com', '2003-09-05', '50342.74'),
#  ('Baane Mini Imports', '2003-02-16', '50218.95'),
#  ('Land of Toys Inc.', '2004-12-02', '50025.35'),
#  ('Reims Collectables', '2005-01-10', '49705.52'),
#  ('Saveley & Henriot, Co.', '2004-01-16', '49614.72'),
#  ('Euro+ Shopping Channel', '2003-10-26', '49539.37'),
#  ('La Rochelle Gifts', '2005-02-22', '49523.67'),
#  ('Auto Canal+ Petit', '2004-01-28', '49165.16'),
#  ('Tokyo Collectables, Ltd', '2004-11-29', '48927.64'),
#  ('Scandinavian Gift Ideas', '2004-09-30', '48809.90'),
#  ('AV Stores, Co.', '2003-03-27', '48425.69'),
#  ('FunGiftIdeas.com', '2004-11-27', '48355.87'),
#  ('Amica Models & Co.', '2004-09-04', '48298.99'),
#  ('La Rochelle Gifts', '2004-08-08', '47924.19'),
#  ('Iberia Gift Imports, Corp.', '2003-11-29', '47513.19'),
#  ("Marta's Replicas Co.", '2004-10-28', '47411.33'),
#  ('Vida Sport, Ltd', '2004-03-13', '47375.92'),
#  ('Osaka Souveniers Co.', '2004-01-19', '47177.59'),
#  ('AV Stores, Co.', '2004-12-08', '47159.11'),
#  ('Mini Gifts Distributors Ltd.', '2004-12-27', '47142.70'),
#  ('Danish Wholesale Imports', '2004-07-03', '4710.73'),
#  ('Euro+ Shopping Channel', '2005-05-19', '46895.48'),
#  ('giftsbymail.co.uk', '2004-11-16', '46788.14'),
#  ('Corporate Gift Ideas Co.', '2005-03-15', '46781.66'),
#  ('Oulu Toy Supplies, Inc.', '2005-02-15', '46770.52'),
#  ('Reims Collectables', '2005-06-09', '46656.94'),
#  ('Mini Caravy', '2004-06-21', '4632.31'),
#  ('Motor Mint Distributors Inc.', '2004-11-23', '45994.07'),
#  ('Australian Collectors, Co.', '2003-05-20', '45864.03'),
#  ('Suominen Souveniers', '2005-01-27', '45785.34'),
#  ('King Kong Collectables, Co.', '2003-12-09', '45480.79'),
#  ('Petit Auto', '2004-08-09', '45352.47'),
#  ('Mini Gifts Distributors Ltd.', '2003-11-25', '45084.38'),
#  ('Australian Collectors, Co.', '2004-03-10', '44894.74'),
#  ('Boards & Toys Co.', '2003-10-18', '4465.85'),
#  ('Vitachrome Inc.', '2004-11-16', '44400.50'),
#  ('Dragon Souveniers, Ltd.', '2003-04-22', '44380.15'),
#  ('Online Mini Collectables', '2004-09-24', '4424.40'),
#  ('Handji Gifts& Co', '2004-07-07', '44160.92'),
#  ('Mini Gifts Distributors Ltd.', '2004-03-26', '43369.30'),
#  ("Marta's Replicas Co.", '2004-09-05', '43134.04'),
#  ('Salzburg Collectables', '2004-11-27', '42813.83'),
#  ('Daedalus Designs Imports', '2003-11-22', '42783.81'),
#  ('Mini Classics', '2004-11-06', '42339.76'),
#  ('Gift Depot Inc.', '2004-07-10', '42044.77'),
#  ("Anna's Decorations, Ltd", '2003-09-28', '41554.73'),
#  ('Mini Creations Ltd.', '2003-08-20', '41016.75'),
#  ('Saveley & Henriot, Co.', '2004-03-18', '40978.53'),
#  ('Enaco Distributors', '2003-12-14', '40473.86'),
#  ('Euro+ Shopping Channel', '2003-02-25', '40206.20'),
#  ('Muscle Machine Inc', '2004-12-14', '39964.63'),
#  ('Saveley & Henriot, Co.', '2003-12-10', '39712.10'),
#  ('Toys4GrownUps.com', '2005-02-06', '39580.60'),
#  ('Down Under Souveniers, Inc', '2004-12-24', '39440.59'),
#  ('Toys4GrownUps.com', '2003-12-04', '3879.96'),
#  ('Handji Gifts& Co', '2004-09-16', '38785.48'),
#  ('Technics Stores Inc.', '2003-08-05', '38675.13'),
#  ("Anna's Decorations, Ltd", '2003-11-13', '38547.19'),
#  ("L'ordine Souveniers", '2003-11-18', '38524.29'),
#  ('Super Scale Inc.', '2003-12-05', '38139.18'),
#  ('Rovelli Gifts', '2003-11-24', '37723.79'),
#  ('Rovelli Gifts', '2004-12-05', '37654.09'),
#  ('Toys of Finland, Co.', '2003-10-27', '37602.48'),
#  ('Royal Canadian Collectables, Ltd.', '2004-08-30', '37527.58'),
#  ('Stylish Desk Decors, Co.', '2003-11-23', '37455.77'),
#  ('Down Under Souveniers, Inc', '2004-06-24', '37281.36'),
#  ('UK Collectables, Ltd.', '2004-06-15', '37258.94'),
#  ('Norway Gifts By Mail, Co.', '2003-10-24', '36798.88'),
#  ('Canadian Gift Exchange Network', '2003-12-18', '36527.61'),
#  ('GiftsForHim.com', '2004-05-15', '36442.34'),
#  ('Euro+ Shopping Channel', '2003-07-19', '36251.03'),
#  ('Heintze Collectables', '2003-10-31', '36164.46'),
#  ('Euro+ Shopping Channel', '2004-11-01', '36140.38'),
#  ('Mini Classics', '2003-12-07', '36092.40'),
#  ('West Coast Collectables Co.', '2004-02-13', '36070.47'),
#  ('Mini Caravy', '2004-05-04', '36069.26'),
#  ('Volvo Model Replicas, Co', '2004-12-12', '36005.71'),
#  ('Salzburg Collectables', '2003-05-12', '35826.33'),
#  ('Souveniers And Things Co.', '2004-08-02', '35806.73'),
#  ('Australian Collectables, Ltd', '2003-12-10', '35505.63'),
#  ('Euro+ Shopping Channel', '2004-07-09', '35420.74'),
#  ('Land of Toys Inc.', '2004-09-11', '35321.97'),
#  ('Dragon Souveniers, Ltd.', '2005-03-27', '3516.04'),
#  ('Mini Caravy', '2005-05-03', '35157.75'),
#  ('Diecast Classics Inc.', '2004-11-19', '35152.12'),
#  ('Extreme Desk Decorations, Ltd', '2004-07-25', '35034.57'),
#  ('Iberia Gift Imports, Corp.', '2004-10-26', '3474.66'),
#  ('Baane Mini Imports', '2004-11-28', '34638.14'),
#  ('Classic Gift Ideas, Inc', '2003-11-28', '34606.28'),
#  ('Boards & Toys Co.', '2005-03-02', '3452.75'),
#  ('Toys of Finland, Co.', '2004-10-21', '34341.08'),
#  ('Tokyo Collectables, Ltd', '2005-02-14', '33967.73'),
#  ('Amica Models & Co.', '2004-09-19', '33924.24'),
#  ('Blauer See Auto, Co.', '2004-03-24', '33820.62'),
#  ('Alpha Cognac', '2003-11-22', '33818.34'),
#  ('Canadian Gift Exchange Network', '2004-11-08', '33594.58'),
#  ("La Corne D'abondance, Co.", '2003-04-20', '33383.14'),
#  ('Signal Gift Stores', '2004-08-20', '33347.88'),
#  ('Corrida Auto Replicas, Ltd', '2004-11-15', '33145.56'),
#  ('Oulu Toy Supplies, Inc.', '2003-10-06', '32723.04'),
#  ('Collectables For Less Inc.', '2003-09-16', '32680.31'),
#  ('Signal Gift Stores', '2003-06-06', '32641.98'),
#  ('Clover Collections, Co.', '2004-03-01', '32538.74'),
#  ('Norway Gifts By Mail, Co.', '2004-09-05', '32260.16'),
#  ('Super Scale Inc.', '2004-05-12', '32239.47'),
#  ("Kelly's Gift Shop", '2003-07-16', '32077.44'),
#  ('Souveniers And Things Co.', '2005-01-03', '31835.36'),
#  ('Extreme Desk Decorations, Ltd', '2004-04-14', '31670.37'),
#  ('CAF Imports', '2003-11-24', '31428.21'),
#  ('Bavarian Collectables Imports, Co.', '2004-09-28', '31310.09'),
#  ('Tekni Collectables Inc.', '2004-05-30', '31102.85'),
#  ('Enaco Distributors', '2003-05-09', '3101.40'),
#  ('FunGiftIdeas.com', '2005-04-15', '30293.77'),
#  ("Kelly's Gift Shop", '2005-05-25', '30253.75'),
#  ('Signal Collectibles Ltd.', '2003-09-28', '29997.09'),
#  ("Anna's Decorations, Ltd", '2005-04-30', '29848.52'),
#  ('Suominen Souveniers', '2003-08-16', '29716.86'),
#  ('Stylish Desk Decors, Co.', '2003-07-07', '29429.14'),
#  ('Royal Canadian Collectables, Ltd.', '2004-04-24', '29284.42'),
#  ('Québec Home Shopping Network', '2005-05-20', '29070.38'),
#  ('Down Under Souveniers, Inc', '2003-07-05', '2880.00'),
#  ('Gift Depot Inc.', '2005-05-19', '28500.78'),
#  ('Suominen Souveniers', '2004-05-22', '28394.54'),
#  ('Collectables For Less Inc.', '2005-02-12', '28322.83'),
#  ('Danish Wholesale Imports', '2004-04-26', '28211.70'),
#  ('Toms Spezialitäten, Ltd', '2003-12-07', '27988.47'),
#  ('Scandinavian Gift Ideas', '2005-04-18', '27966.54'),
#  ('Microscale Inc.', '2004-11-13', '27550.51'),
#  ('Mini Auto Werke', '2003-11-15', '27121.90'),
#  ("Anna's Decorations, Ltd", '2005-02-09', '27083.78'),
#  ('Lyon Souveniers', '2004-12-30', '26311.63'),
#  ('Gift Ideas Corp.', '2004-12-17', '26304.13'),
#  ('Mini Wheels Co.', '2004-12-08', '26248.78'),
#  ('Euro+ Shopping Channel', '2004-05-17', '26155.91'),
#  ('Dragon Souveniers, Ltd.', '2004-08-11', '2611.84'),
#  ('Motor Mint Distributors Inc.', '2003-03-20', '25833.14'),
#  ('Classic Legends Inc.', '2004-12-07', '25505.98'),
#  ('Auto Canal+ Petit', '2004-06-17', '25080.96'),
#  ('giftsbymail.co.uk', '2004-03-28', '24995.61'),
#  ('Enaco Distributors', '2004-12-06', '24945.21'),
#  ('Gift Depot Inc.', '2003-11-19', '24879.08'),
#  ('Technics Stores Inc.', '2004-11-14', '2434.25'),
#  ('Blauer See Auto, Co.', '2003-10-18', '24101.81'),
#  ('Souveniers And Things Co.', '2003-08-03', '24013.52'),
#  ('Australian Gift Network, Co', '2003-11-15', '23936.53'),
#  ('Mini Wheels Co.', '2003-12-11', '23923.93'),
#  ('UK Collectables, Ltd.', '2003-10-20', '23908.24'),
#  ('Toys of Finland, Co.', '2005-03-10', '23602.90'),
#  ('Lyon Souveniers', '2003-07-18', '23419.47'),
#  ('Classic Gift Ideas, Inc', '2004-10-24', '23333.06'),
#  ('Québec Home Shopping Network', '2004-07-01', '22997.45'),
#  ('Vitachrome Inc.', '2004-04-25', '22602.36'),
#  ('Handji Gifts& Co', '2004-02-28', '22474.17'),
#  ('Land of Toys Inc.', '2003-03-12', '22292.62'),
#  ('Double Decker Gift Stores, Ltd', '2003-12-04', '22275.73'),
#  ('Corrida Auto Replicas, Ltd', '2004-02-06', '22162.61'),
#  ('Classic Legends Inc.', '2003-10-31', '22042.37'),
#  ('Tokyo Collectables, Ltd', '2004-06-21', '22037.91'),
#  ('Classic Legends Inc.', '2003-04-16', '21665.98'),
#  ('Australian Gift Network, Co', '2005-03-01', '21432.31'),
#  ("Men 'R' US Retailers, Ltd.", '2004-01-18', '21053.69'),
#  ('Cruz & Sons Co.', '2003-12-02', '20644.24'),
#  ('Danish Wholesale Imports', '2004-12-01', '20564.86'),
#  ("Men 'R' US Retailers, Ltd.", '2003-10-24', '20452.50'),
#  ('Cambridge Collectables Co.', '2004-03-29', '20355.24'),
#  ('Muscle Machine Inc', '2004-07-26', '20314.44'),
#  ('GiftsForHim.com', '2003-12-16', '20220.04'),
#  ('Euro+ Shopping Channel', '2004-08-16', '20009.53'),
#  ("La Corne D'abondance, Co.", '2004-09-09', '1960.80'),
#  ('La Rochelle Gifts', '2004-11-14', '19501.82'),
#  ('Daedalus Designs Imports', '2004-03-15', '18997.89'),
#  ('Marseille Mini Autos', '2004-12-11', '18888.31'),
#  ('Gifts4AllAges.com', '2004-07-11', '18473.71'),
#  ('Marseille Mini Autos', '2005-01-29', '1834.56'),
#  ('Lyon Souveniers', '2005-05-17', '17928.09'),
#  ('Baane Mini Imports', '2004-11-04', '17876.32'),
#  ('Frau da Collezione', '2003-10-27', '17746.26'),
#  ('Clover Collections, Co.', '2004-10-03', '17359.53'),
#  ('Gift Ideas Corp.', '2003-06-25', '17032.29'),
#  ('Québec Home Shopping Network', '2003-11-18', '16909.84'),
#  ('Petit Auto', '2004-03-03', '16901.38'),
#  ('Microscale Inc.', '2004-04-30', '1679.92'),
#  ('Atelier graphique', '2004-12-18', '1676.14'),
#  ('Reims Collectables', '2003-05-21', '16700.47'),
#  ('Mini Wheels Co.', '2003-04-09', '16537.85'),
#  ('Royale Belge', '2003-04-19', '1627.56'),
#  ('Oulu Toy Supplies, Inc.', '2004-04-25', '16212.59'),
#  ('Cruz & Sons Co.', '2004-11-19', '15822.84'),
#  ('CAF Imports', '2004-04-02', '15322.93'),
#  ('Osaka Souveniers Co.', '2004-04-17', '15183.63'),
#  ('Mini Auto Werke', '2003-11-20', '15130.97'),
#  ('Gifts4AllAges.com', '2004-09-21', '15059.76'),
#  ('Baane Mini Imports', '2003-10-28', '1491.38'),
#  ('Atelier graphique', '2003-06-05', '14571.44'),
#  ('Royale Belge', '2005-02-03', '14379.90'),
#  ('Alpha Cognac', '2003-07-21', '14232.70'),
#  ('Signal Gift Stores', '2004-12-17', '14191.12'),
#  ('Reims Collectables', '2003-07-21', '13920.26'),
#  ('Stylish Desk Decors, Co.', '2004-12-13', '13671.82'),
#  ('Technics Stores Inc.', '2005-02-02', '12692.19'),
#  ('Signal Collectibles Ltd.', '2004-02-29', '12573.28'),
#  ('Herkku Gifts', '2004-09-19', '12538.01'),
#  ('Collectables For Less Inc.', '2004-08-02', '12530.51'),
#  ('Alpha Cognac', '2005-06-03', '12432.32'),
#  ('Auto Canal+ Petit', '2005-04-23', '12190.85'),
#  ('Royale Belge', '2004-12-03', '12081.52'),
#  ('Euro+ Shopping Channel', '2005-03-18', '120166.58'),
#  ('Cambridge Collectables Co.', '2004-05-13', '11843.45'),
#  ('Euro+ Shopping Channel', '2004-12-31', '116208.40'),
#  ('Royale Belge', '2003-08-22', '1128.20'),
#  ('Mini Gifts Distributors Ltd.', '2003-08-15', '111654.40'),
#  ('Mini Gifts Distributors Ltd.', '2003-04-11', '11044.30'),
#  ('Dragon Souveniers, Ltd.', '2003-12-26', '105743.00'),
#  ('Blauer See Auto, Co.', '2003-01-28', '10549.01'),
#  ('Online Diecast Creations Co.', '2003-01-16', '10223.83'),
#  ('Mini Gifts Distributors Ltd.', '2005-03-05', '101244.59')]

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of customer first and last names, product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries which can make complex queries such as this much simpler!

# %%
# Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on one-to-many and many-to-many relationships!
